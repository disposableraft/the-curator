# %%
from pygraphviz import *
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

data = {'albertalcalai': {'similar': {'louischanker'}, 'in_category_mean': 0.1}, 'williambaziot': {'similar': {'marktobei', 'theodorroszak', 'theodorostamo', 'jamebrook'}, 'in_category_mean': 0.4}, 'louisbourgeoi': {'similar': {'herbertferber', 'gracehartigan', 'jamerosati'}, 'in_category_mean': 0.3}, 'ernestbrigg': {'similar': {'josephgoto'}, 'in_category_mean': 0.1}, 'jamebrook': {'similar': {'charlselig', 'hanhofmann', 'raoulhagu', 'williambaziot'}, 'in_category_mean': 0.4}, 'alexandcalder': {'similar': {'davidsmith', 'jacksonpollock', 'arshilgorki', 'theodorroszak', 'willemkoon', 'herbertferber'}, 'in_category_mean': 0.6}, 'giorgiocavallon': {'similar': {'morriloui', 'philipguston', 'estebanvicent', 'leekrasner', 'michaelgoldberg'}, 'in_category_mean': 0.5}, 'johnchamberlain': {'similar': {'twombl'}, 'in_category_mean': 0.1}, 'josephcornel': {'similar': {'helenfrankenthal', 'robertmotherwel', 'reinhardt', 'willemkoon', 'gracehartigan'}, 'in_category_mean': 0.5}, 'elainkoon': {'similar': {'michaelgoldberg'}, 'in_category_mean': 0.1}, 'willemkoon': {'similar': {'alexandcalder', 'jacksonpollock', 'reinhardt', 'robertmotherwel'}, 'in_category_mean': 0.4}, 'richarddiebenkorn': {'similar': {'johnchamberlain'}, 'in_category_mean': 0.1}, 'herbertferber': {'similar': {'davidsmith', 'richardlippold', 'ibramlassaw', 'louisbourgeoi', 'isamunoguchi', 'theodorroszak', 'alexandcalder'}, 'in_category_mean': 0.7}, 'samfranci': {'similar': {'johnchamberlain', 'reinhardt', 'louisnevelson', 'robertmotherwel'}, 'in_category_mean': 0.4}, 'helenfrankenthal': {'similar': {'robertmotherwel', 'willemkoon', 'joanmitchel', 'louisnevelson'}, 'in_category_mean': 0.4}, 'soniagechtoff': {'similar': {'richardpousettdart'}, 'in_category_mean': 0.1}, 'michaelgoldberg': {'similar': {'alfrlesli', 'elainkoon'}, 'in_category_mean': 0.2}, 'robertgoodnough': {'similar': {'barnettnewman', 'miltonresnick'}, 'in_category_mean': 0.2}, 'arshilgorki': {'similar': {'alexandcalder', 'marktobei', 'willemkoon', 'jacksonpollock'}, 'in_category_mean': 0.4}, 'adolphgottlieb': {'similar': {'giorgiocavallon', 'gracehartigan', 'estebanvicent', 'clyfford'}, 'in_category_mean': 0.4}, 'morrigrave': {'similar': {'jacksonpollock', 'reinhardt', 'willemkoon', 'alexandcalder'}, 'in_category_mean': 0.4}, 'philipguston': {'similar': {'johnchamberlain', 'richarddiebenkorn', 'giorgiocavallon', 'morriloui'}, 'in_category_mean': 0.4}, 'raoulhagu': {'similar': {'jamebrook'}, 'in_category_mean': 0.1}, 'davidhare': {'similar': {'davidsmith', 'ibramlassaw', 'theodorroszak', 'alexandcalder'}, 'in_category_mean': 0.4}, 'gracehartigan': {'similar': {'helenfrankenthal', 'louisbourgeoi', 'willemkoon', 'markrothko', 'alfrlesli'}, 'in_category_mean': 0.5}, 'hanhofmann': {'similar': {'seymourlipton', 'jamebrook'}, 'in_category_mean': 0.2}, 'franzkline': {'similar': {'helenfrankenthal', 'robertmotherwel', 'arshilgorki', 'reinhardt', 'willemkoon'}, 'in_category_mean': 0.5}, 'leekrasner': {'similar': {'giorgiocavallon', 'morriloui', 'philipguston', 'estebanvicent', 'thomasill'}, 'in_category_mean': 0.5}, 'ibramlassaw': {'similar': {'herbertferber', 'theodorroszak'}, 'in_category_mean': 0.2}, 'alfrlesli': {'similar': {'gracehartigan', 'michaelgoldberg'}, 'in_category_mean': 0.2}, 'richardlippold': {'similar': {'davidsmith', 'theodorroszak', 'reinhardt', 'marktobei', 'alexandcalder'}, 'in_category_mean': 0.5}, 'seymourlipton': {'similar': {'hanhofmann', 'raoulhagu', 'jamebrook'}, 'in_category_mean': 0.3}, 'morriloui': {'similar': {'leekrasner', 'giorgiocavallon', 'philipguston'}, 'in_category_mean': 0.3}, 'conradmarcarelli': {'similar': {'hanhofmann', 'arshilgorki', 'raoulhagu', 'bradleiwalkertomlin', 'jamebrook'}, 'in_category_mean': 0.5}, 'nicholamarsicano': {'similar': {'hanhofmann', 'giorgiocavallon', 'clyfford', 'estebanvicent', 'jacktworkov', 'thomasill'}, 'in_category_mean': 0.6}, 'joanmitchel': {'similar': {'helenfrankenthal', 'twombl', 'robertmotherwel', 'louisnevelson'}, 'in_category_mean': 0.4}, 'robertmotherwel': {'similar': {'helenfrankenthal', 'reinhardt', 'jacksonpollock', 'willemkoon'}, 'in_category_mean': 0.4}, 'louisnevelson': {'similar': {'helenfrankenthal', 'joanmitchel'}, 'in_category_mean': 0.2}, 'barnettnewman': {'similar': {'helenfrankenthal', 'louisnevelson', 'jamerosati', 'philipguston', 'robertgoodnough', 'markrothko', 'miltonresnick'}, 'in_category_mean': 0.7}, 'isamunoguchi': {'similar': {'davidsmith', 'herbertferber', 'theodorroszak', 'reinhardt', 'willemkoon', 'alexandcalder'}, 'in_category_mean': 0.6}, 'jacksonpollock': {'similar': {'willemkoon'}, 'in_category_mean': 0.1}, 'richardpousettdart': {'similar': {'soniagechtoff'}, 'in_category_mean': 0.1}, 'reinhardt': {'similar': {'alexandcalder', 'willemkoon', 'josephcornel', 'robertmotherwel'}, 'in_category_mean': 0.4}, 'miltonresnick': {'similar': {'robertgoodnough', 'barnettnewman'}, 'in_category_mean': 0.2}, 'jeanpaulriopel': {'similar': {'jackbush'}, 'in_category_mean': 0.1}, 'jamerosati': {'similar': {'barnettnewman', 'louisbourgeoi'}, 'in_category_mean': 0.2}, 'theodorroszak': {'similar': {'davidsmith', 'herbertferber', 'davidhare', 'alexandcalder'}, 'in_category_mean': 0.4}, 'markrothko': {'similar': {'helenfrankenthal', 'louisnevelson', 'robertmotherwel', 'barnettnewman', 'willemkoon', 'reinhardt', 'jacksonpollock', 'gracehartigan'}, 'in_category_mean': 0.8}, 'charlselig': {'similar': {'enricodonati', 'jamebrook'}, 'in_category_mean': 0.2}, 'thomasill': {'similar': {'morriloui', 'nicholamarsicano', 'estebanvicent', 'jacktworkov', 'leekrasner'}, 'in_category_mean': 0.5}, 'davidsmith': {'similar': {'alexandcalder', 'isamunoguchi', 'theodorroszak'}, 'in_category_mean': 0.3}, 'theodorostamo': {'similar': {'enricodonati', 'marktobei', 'williambaziot'}, 'in_category_mean': 0.3}, 'heddastern': {'similar': {'davidsmith', 'arshilgorki'}, 'in_category_mean': 0.2}, 'clyfford': {'similar': {'adolphgottlieb', 'giorgiocavallon', 'morriloui', 'nicholamarsicano', 'jacktworkov'}, 'in_category_mean': 0.5}, 'marktobei': {'similar': {'alexandcalder', 'jacksonpollock', 'arshilgorki'}, 'in_category_mean': 0.3}, 'bradleiwalkertomlin': {'similar': {'jamebrook', 'arshilgorki', 'willemkoon', 'markrothko', 'williambaziot', 'jacksonpollock'}, 'in_category_mean': 0.6}, 'twombl': {'similar': {'johnchamberlain'}, 'in_category_mean': 0.1}, 'jacktworkov': {'similar': {'giorgiocavallon', 'clyfford', 'estebanvicent', 'leekrasner', 'thomasill'}, 'in_category_mean': 0.5}, 'estebanvicent': {'similar': {'giorgiocavallon', 'morriloui', 'jacktworkov', 'leekrasner', 'thomasill'}, 'in_category_mean': 0.5}}

# %%
G = AGraph(
    directed=True,
    size="10,10",
    overlap=False,
    concentrate=True
)

for t1 in data:
    G.add_node(t1, 
               shape="oval",
               label=f'{data[t1]["in_category_mean"]}\n{t1}',
               style="filled",
               color="#cccccc cc"
              )

    for n in data[t1]['similar']:
        G.add_edge(t1, n, 
                   arrowhead="vee", 
                   color="pink",
                   # dir="both"
                   # concentrate=True
                  )


G.layout()
G.draw('./similar-artists.png')

img = mpimg.imread('./similar-artists.png')

plt.imshow(img)

# %%
G.layout()
G.draw('similar-artists.png')

# %%
help(pygraphviz)
# Out:
# Help on package pygraphviz:
#
# NAME
#     pygraphviz - A Python wrapper for the graphviz Agraph data structure.
#
# DESCRIPTION
#     Quick example::
#
#     >>> from pygraphviz import *
#     >>> G=AGraph()
#     >>> G.add_node('a')
#     >>> G.add_edge('b','c')
#     >>> print G  # doctest: +SKIP
#     strict graph {
#         a;
#         b -- c;
#     }
#     <BLANKLINE>
#
#     See pygraphviz.AGraph for detailed documentation.
#
# PACKAGE CONTENTS
#     _graphviz
#     agraph
#     graphviz
#     release
#     tests (package)
#     version
#
# CLASSES
#     builtins.ValueError(builtins.Exception)
#         pygraphviz.agraph.DotError
#     builtins.object
#         pygraphviz.agraph.AGraph
#     builtins.str(builtins.object)
#         pygraphviz.agraph.Node
#     builtins.tuple(builtins.object)
#         pygraphviz.agraph.Edge
#     collections.abc.MutableMapping(collections.abc.Mapping)
#         pygraphviz.agraph.Attribute
#             pygraphviz.agraph.ItemAttribute
#
# ...
