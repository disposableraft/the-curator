# %% [markdown]
# # MoMA Artworks and Artists
#
# This notebook takes a look at the original exhibition data.
#
# - https://www.kaggle.com/momanyc/museum-collection/downloads/museum-collection.zip/1
# - Artists and artworks from the MoMA collection

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.0MB 2.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 512kB 758kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.1MB 2.2MB/s eta 0:00:01    |██████████████                  | 6.6MB 2.9MB/s eta 0:00:03     |██████████████████████████▎     | 12.4MB 2.0MB/s eta 0:00:02
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
artist_df = pd.read_csv('~/data1/moma/artists.csv')
artwork_df = pd.read_csv('~/data1/moma/artworks.csv')
exh_df = pd.read_csv('~/data1/moma/exhibitions/MoMAExhibitions1929to1989.csv', encoding="iso8859-1")

# %%
artist_df.head(100)
# Out:
#     Artist ID                                    Name Nationality  Gender  \
# 0           1                          Robert Arneson    American    Male
# 1           2                          Doroteo Arnaiz     Spanish    Male
# 2           3                             Bill Arnold    American    Male
# 3           4                         Charles Arnoldi    American    Male
# 4           5                             Per Arnoldi      Danish    Male
# 5           6                           Danilo Aroldi     Italian    Male
# 6           7                               Bill Aron    American    Male
# 7           9                           David Aronson    American    Male
# 8          10                           Irene Aronson    American  Female
# 9          11                         Jean (Hans) Arp      French    Male
# 10         12                              Jüri Arrak    Estonian    Male
# 11         13                     J. Arrelano Fischer     Mexican    Male
# ...

# %%
artwork_df.head()
# Out:
#    Artwork ID                                              Title Artist ID  \
# 0           2  Ferdinandsbrücke Project, Vienna, Austria, Ele...      6210
# 1           3  City of Music, National Superior Conservatory ...      7470
# 2           4  Villa near Vienna Project, Outside Vienna, Aus...      7605
# 3           5  The Manhattan Transcripts Project, New York, N...      7056
# 4           6  Villa, project, outside Vienna, Austria, Exter...      7605
#
#                        Name  Date  \
# 0               Otto Wagner  1896
# 1  Christian de Portzamparc  1987
# 2                Emil Hoppe  1903
# 3           Bernard Tschumi  1980
# 4                Emil Hoppe  1903
#
#                                               Medium  \
# 0      Ink and cut-and-pasted painted pages on paper
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# 3  Photographic reproduction with colored synthet...
# ...

# %%
exh_df.head()
# Out:
#    ExhibitionID ExhibitionNumber                     ExhibitionTitle  \
# 0        2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 1        2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 2        2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 3        2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
# 4        2557.0                1  Cézanne, Gauguin, Seurat, Van Gogh
#
#                         ExhibitionCitationDate ExhibitionBeginDate  \
# 0  [MoMA Exh. #1, November 7-December 7, 1929]           11/7/1929
# 1  [MoMA Exh. #1, November 7-December 7, 1929]           11/7/1929
# 2  [MoMA Exh. #1, November 7-December 7, 1929]           11/7/1929
# 3  [MoMA Exh. #1, November 7-December 7, 1929]           11/7/1929
# 4  [MoMA Exh. #1, November 7-December 7, 1929]           11/7/1929
#
#   ExhibitionEndDate  ExhibitionSortOrder                       ExhibitionURL  \
# ...

# %% [markdown]
# ## Curators and Artists
#
# The following two cells show counts for rows about curators and artists. There are **1495** rows with ExhibitionRole Curator and **32537** with Artist.

# %%
len(exh_df.loc[exh_df['ExhibitionRole'] == 'Curator'])
# Out:
# 1495

# %%
len(exh_df.loc[exh_df['ExhibitionRole'] == 'Artist'])
# Out:
# 32537

# %% [markdown]
# ## Total Exhibitions
#
# The total number of unique exhibition IDs is **1728**.

# %%
len(exhibition_data.ExhibitionID.unique())
# Out:
# 1728

# %% [markdown]
# _But_ the total number of unique titles is **1667**. Some are named _Untitled_?

# %%
len(exhibition_data.ExhibitionTitle.unique())
# Out:
# 1667

# %% [markdown]
# _And_ the total unique for exhibition numbers is **1735**.

# %%
len(exhibition_data.ExhibitionNumber.unique())
# Out:
# 1735

# %% [markdown]
# The mean is **1710**. So somewhere around here ...

# %%
sum([1728,1667,1735]) / 3
# Out:
# 1710.0

# %% [markdown]
# # Do the datasets match up?
#
# Let's see if the artist ids from exhibitions and artists and artists tables match.
#
# Answer: They almost match up. The exhibition data doesn't include an artist ID on its own, but it does include a `ConstituentURL`, and the last part of that is the artist ID.

# %%
artist_data.loc[artist_data['Artist ID'] == 2714]
# Out:
#       Artist ID          Name Nationality  Gender  Birth Year  Death Year
# 2422       2714  Jenny Holzer    American  Female      1950.0         NaN

# %%
artwork_data.loc[artwork_data['Artist ID'] == '2714']
# Out:
#         Artwork ID                                              Title  \
# 35073        37309                   LAMENTS: THE NEW DISEASE CAME...
# 57592        61299  With You Inside Me Comes the Knowledge of My D...
# 59876        63755                                            Truisms
# 75114        81084                                            Laments
# 75383        81421                                      Electric Sign
# 75386        81424                                      Granite Bench
# 79787        87284                        Laments (I Want to Live...)
# 84536        96197             LAMENTS: THE KNIFE CUT RUNS AS LONG...
# 90006       106989    Living: You should limit the number of times...
# 90007       106990  Living: More than once I've wakened with tears...
# 90008       106991      Living: Some days you wake and immediately...
# 90009       106992  Living: More people will be building hiding pl...
# ...

# %%
exh_df.loc[lambda df: df['ConstituentURL'] == 'moma.org/artists/2714']
# Out:
#        ExhibitionID ExhibitionNumber     ExhibitionTitle  \
# 33452         479.0             1473  Committed to Print
#
#                              ExhibitionCitationDate ExhibitionBeginDate  \
# 33452  [MoMA Exh. #1473, January 31-April 19, 1988]           1/31/1988
#
#       ExhibitionEndDate  ExhibitionSortOrder  \
# 33452         4/19/1988               1693.0
#
#                             ExhibitionURL ExhibitionRole  \
# 33452  moma.org/calendar/exhibitions/1762         Artist
#
#       ExhibitionRoleinPressRelease  ...  Institution Nationality  \
# 33452                       Artist  ...          NaN    American
#
#       ConstituentBeginDate ConstituentEndDate            ArtistBio  Gender  \
# 33452               1950.0                NaN  American, born 1950  Female
#
#             VIAFID WikidataID       ULANID         ConstituentURL
# 33452  114074273.0    Q270388  500047276.0  moma.org/artists/2714
#
# [1 rows x 28 columns]

# %% [markdown]
# # A List of Exhibition Names

# %%
titles = exhibition_data['ExhibitionTitle'].unique()

titles.sort()
for t in titles:
    print(t)
# Out:
# "Primitivism" in 20th Century Art: Affinity of the Tribal and the Modern
# "That's Not All Folks!":  Warner Bros. Cartoons Golden Jubilee
# 100 Drawings from the Museum Collection
# 100 Useful Objects of Fine Design (available under $100)
# 12 Photographers
# 15 Americans
# 16 Americans
# 20 Drawings: New Acquisitions
# 20 Gifts in Honor of Myron Orlofsky
# 20th Century Design from the Museum Collection
# 20th Century Sculpture and Constructions
# 25 Recent Acquisitions
# 25 Years of James Bond: Gift of Albert R. Broccoli
# 2nd Floor Installation
# 30th Anniversary Special Installation - Towards the "New" Museum
# 40 Prints from the Collection
# 44 Drawings: Recent Acquisitions
# 46 Painters and Sculptors under 35 Years of Age
# 46 Recent Lithographs by Picasso
# 50 Photographs by 50 Photographers
# 50 Selections from the Collection of Mr. and Mrs. Walter Bareiss
# 60 Modern Drawings: Recent Acquisitions
# 70 Photographers Look at New York
# 76 Jefferson
# 8 Automobiles
# ...

# %% [markdown]
# # A List of Artist Names

# %%
names = artist_data['Name']

[print(n) for n in names].sort()
# Out:
# Robert Arneson
# Doroteo Arnaiz
# Bill Arnold
# Charles Arnoldi
# Per Arnoldi
# Danilo Aroldi
# Bill Aron
# David Aronson
# Irene Aronson
# Jean (Hans) Arp
# Jüri Arrak
# J. Arrelano Fischer
# Folke Arstrom
# Cristobal Arteche
# Artko
# Richard Artschwager
# Ruth Asawa
# Isidora Aschheim
# Charles Robert Ashbee
# Donald Ashcraft
# E. M. Ashe
# Göran Åslin
# Erik Gunnar Asplund
# Geneviève Asse
# Sergio Asti
# Dana Atchley
# Atelier Eggers
# A.A.P.
# Alvar Aalto
# Aino Aalto
# Eero Aarnio
# Jules Aarons
# Magdalena Abakanowicz
# James Abbe
# Jussuff Abbo
# Berenice Abbott
# Nobuya Abe
# Abe Shiro (pen Name: Suichiku)
# Robert Abel
# Sigmund Abeles
# Raimund Abraham
# Ivor Abrahams
# Gerald Abramovitz
# William Ross Abrams
# Rodolfo Abularach
# Vito Acconci
# Milton Ackoff
# Norman Ackroyd
# Luis Alberto Acuña
# Henri Georges Adam
# Antoine Samuel Adam-Salomon
# Valerio Adami
# Ansel Adams
# Alice Adams
# Clinton Adams
# Dacres Adams
# Dennis Adams
# Kenneth M. Adams
# Robert Adams
# ...

# %%
exhibition_data.loc[exhibition_data['ExhibitionNumber'] == 'No#']
# Out:
#        ExhibitionID ExhibitionNumber  \
# 3620        10600.0              No#
# 6274            NaN              No#
# 6275            NaN              No#
# 6276            NaN              No#
# 6277            NaN              No#
# 6278            NaN              No#
# 6457            NaN              No#
# 6598            NaN              No#
# 6616            NaN              No#
# 7308         4460.0              No#
# 7328            NaN              No#
# 9251            NaN              No#
# 12864           NaN              No#
# 12917           NaN              No#
# 12918           NaN              No#
# 12919           NaN              No#
# 12920           NaN              No#
# 12921           NaN              No#
# 12922           NaN              No#
# 12923           NaN              No#
# 12924           NaN              No#
# 12925           NaN              No#
# 12926           NaN              No#
# 12927           NaN              No#
# ...
