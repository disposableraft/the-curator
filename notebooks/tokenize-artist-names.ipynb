# %% [markdown]
# This notebook compiles a graphable object of similar artists.
#
# **Note** The code has been moved to `../bin`

# %%
from gensim.models import Word2Vec
from gensim.parsing.preprocessing import preprocess_string
from pathlib import Path

# %%
def import_categories(paths):
    categories = {
        # <file name>: [ ...<artists>]
    }

    for path in paths:
        with open(path, mode='r', encoding='utf-8') as file:
            # Split the file path, select the name, then split off the extension
            category_name = file.name.split('/')[-1].split('.')[0]

            data = file.readlines()

            c_name = categories.setdefault(category_name, {})
            c_name['names'] = []
            # strip the artist names and append them to categories.name
            [c_name['names'].append(d.strip()) for d in data]
    return categories

# %% [markdown]
# The above results in an object of categories, each one with a list of artists.
#
# Now, using `preprocess_string`, the names can be tokenized.
#
# That list will then get run through the model to check which names exist in the model and which don't.

# %%
def format_name(names):
    "Join a name with an underscore"
    # process all the names at once.
    return ["".join(preprocess_string(n)) for n in names]

def tokenize_names(categories):
    for c_name in categories:
        c_name = categories[c_name]
        c_name['tokens'] = []
        tokenized_names = format_name(c_name['names'])
        [c_name['tokens'].append(n) for n in tokenized_names]
    return categories

# %%
paths = Path('../data/historical-categories/').glob('*.txt')
categories = import_categories(paths)
categories = tokenize_names(categories)

# %% [markdown]
# Now we have an object for categories with full names and their tokenized forms.
#
# ```python
#
# categories = {
#     'ab-ex-names': {
#         'names': [ ... ],
#         'tokens': [ ... ]
#     },
#     ...
# }
#
# ```

# %%
model = Word2Vec.load('../data/models/moma-combos.model')

# %% [markdown]
# Now that I have the lists of names, it's time to compare them. What I want to know is, how is each category represented in the model?

# %%
def print_category_relevance(C, model_tokens):
    for c_name in C:
        count = 0
        for t in C[c_name]['tokens']:
            if t in model_tokens:
                count += 1
        C[c_name]['tokens_in_model'] = count
        C[c_name]['tokens_in_category'] = len(C[c_name]['tokens'])

    ab_ex = C['ab-ex-artists']
    impressionist = C['impressionist-artists']
    conceptual = C['conceptual-artists']

    print('<category name>: <model> / <category>)')
    print(f'Ab Ex: {ab_ex["tokens_in_model"]} / {ab_ex["tokens_in_category"]}')
    print(f'Impressionist: {impressionist["tokens_in_model"]} / {impressionist["tokens_in_category"]}')
    print(f'Conceptual: {conceptual["tokens_in_model"]} / {conceptual["tokens_in_category"]}')

    
model_tokens = list(model.wv.vocab)

print_category_relevance(categories, model_tokens)
# Out:
# <category name>: <model> / <category>)
# Ab Ex: 76 / 122
# Impressionist: 14 / 52
# Conceptual: 42 / 137

# %% [markdown]
# \begin{equation} A_m ⋂ A_c = A_{cm} \end{equation}
#
# **A_m** Artists in the model
#
# **A_c** Artists in the category
#
# **A_cm** Intersection of A_m and A_c
#
# For each artist that appears in both the category and the model, I want to:
#
# 1. get the N most similar artists (A_ms)
# 2. record the mean of A_cm/A_ms
# 3. count any incoming references from other A_cm

# %%
def graph_artists(tokens, model, top_n_similar=10):
    """
    tokens: A list of tokenized artist names from a category. 
            tokens in category must be the same as in the model.
    model:  The Word2Vec model
    
    Returns object
    
    graph {
        '<token>': {
            similar: [],
            in_category_mean: <int>,
        }
    }
    """
    graph = {}
    
    vocab = list(model.wv.vocab)
    
    for a in tokens:
        if a in vocab:
            node = graph.setdefault(a, {})
            node['similar'] = set()
            similar_a = model.wv.most_similar(a, topn=top_n_similar)
            for s_a, _ in similar_a:
                if s_a in tokens:
                    node['similar'].add(s_a)
            node['in_category_mean'] = len(node['similar']) / top_n_similar
            # Remove the node if there are no similar artists
            if node['in_category_mean'] == 0:
                graph.popitem()

    return graph

graph = graph_artists(categories['ab-ex-artists']['tokens'], model)
graph
# Out:
# {'albertalcalai': {'similar': {'louischanker'}, 'in_category_mean': 0.1},
#  'williambaziot': {'similar': {'jamebrook',
#    'marktobei',
#    'theodorostamo',
#    'theodorroszak'},
#   'in_category_mean': 0.4},
#  'louisbourgeoi': {'similar': {'gracehartigan', 'herbertferber', 'jamerosati'},
#   'in_category_mean': 0.3},
#  'ernestbrigg': {'similar': {'josephgoto'}, 'in_category_mean': 0.1},
#  'jamebrook': {'similar': {'charlselig',
#    'hanhofmann',
#    'raoulhagu',
#    'williambaziot'},
#   'in_category_mean': 0.4},
#  'alexandcalder': {'similar': {'arshilgorki',
#    'davidsmith',
#    'herbertferber',
#    'jacksonpollock',
#    'theodorroszak',
#    'willemkoon'},
#   'in_category_mean': 0.6},
#  'giorgiocavallon': {'similar': {'estebanvicent',
#    'leekrasner',
#    'michaelgoldberg',
#    'morriloui',
#    'philipguston'},
#   'in_category_mean': 0.5},
#  'johnchamberlain': {'similar': {'twombl'}, 'in_category_mean': 0.1},
#  'josephcornel': {'similar': {'gracehartigan',
#    'helenfrankenthal',
#    'reinhardt',
#    'robertmotherwel',
#    'willemkoon'},
#   'in_category_mean': 0.5},
#  'elainkoon': {'similar': {'michaelgoldberg'}, 'in_category_mean': 0.1},
#  'willemkoon': {'similar': {'alexandcalder',
#    'jacksonpollock',
#    'reinhardt',
#    'robertmotherwel'},
#   'in_category_mean': 0.4},
#  'richarddiebenkorn': {'similar': {'johnchamberlain'},
#   'in_category_mean': 0.1},
#  'herbertferber': {'similar': {'alexandcalder',
#    'davidsmith',
#    'ibramlassaw',
#    'isamunoguchi',
#    'louisbourgeoi',
#    'richardlippold',
#    'theodorroszak'},
#   'in_category_mean': 0.7},
#  'samfranci': {'similar': {'johnchamberlain',
#    'louisnevelson',
#    'reinhardt',
#    'robertmotherwel'},
#   'in_category_mean': 0.4},
#  'helenfrankenthal': {'similar': {'joanmitchel',
#    'louisnevelson',
#    'robertmotherwel',
#    'willemkoon'},
#   'in_category_mean': 0.4},
#  'soniagechtoff': {'similar': {'richardpousettdart'}, 'in_category_mean': 0.1},
#  'michaelgoldberg': {'similar': {'alfrlesli', 'elainkoon'},
#   'in_category_mean': 0.2},
#  'robertgoodnough': {'similar': {'barnettnewman', 'miltonresnick'},
#   'in_category_mean': 0.2},
#  'arshilgorki': {'similar': {'alexandcalder',
#    'jacksonpollock',
#    'marktobei',
#    'willemkoon'},
#   'in_category_mean': 0.4},
#  'adolphgottlieb': {'similar': {'clyfford',
#    'estebanvicent',
#    'giorgiocavallon',
#    'gracehartigan'},
#   'in_category_mean': 0.4},
#  'morrigrave': {'similar': {'alexandcalder',
#    'jacksonpollock',
#    'reinhardt',
#    'willemkoon'},
#   'in_category_mean': 0.4},
#  'philipguston': {'similar': {'giorgiocavallon',
#    'johnchamberlain',
#    'morriloui',
#    'richarddiebenkorn'},
#   'in_category_mean': 0.4},
#  'raoulhagu': {'similar': {'jamebrook'}, 'in_category_mean': 0.1},
#  'davidhare': {'similar': {'alexandcalder',
#    'davidsmith',
#    'ibramlassaw',
#    'theodorroszak'},
#   'in_category_mean': 0.4},
#  'gracehartigan': {'similar': {'alfrlesli',
#    'helenfrankenthal',
#    'louisbourgeoi',
#    'markrothko',
#    'willemkoon'},
#   'in_category_mean': 0.5},
#  'hanhofmann': {'similar': {'jamebrook', 'seymourlipton'},
#   'in_category_mean': 0.2},
#  'franzkline': {'similar': {'arshilgorki',
#    'helenfrankenthal',
#    'reinhardt',
#    'robertmotherwel',
#    'willemkoon'},
#   'in_category_mean': 0.5},
#  'leekrasner': {'similar': {'estebanvicent',
#    'giorgiocavallon',
#    'morriloui',
#    'philipguston',
#    'thomasill'},
#   'in_category_mean': 0.5},
#  'ibramlassaw': {'similar': {'herbertferber', 'theodorroszak'},
#   'in_category_mean': 0.2},
#  'alfrlesli': {'similar': {'gracehartigan', 'michaelgoldberg'},
#   'in_category_mean': 0.2},
#  'richardlippold': {'similar': {'alexandcalder',
#    'davidsmith',
#    'marktobei',
#    'reinhardt',
#    'theodorroszak'},
#   'in_category_mean': 0.5},
#  'seymourlipton': {'similar': {'hanhofmann', 'jamebrook', 'raoulhagu'},
#   'in_category_mean': 0.3},
#  'morriloui': {'similar': {'giorgiocavallon', 'leekrasner', 'philipguston'},
#   'in_category_mean': 0.3},
#  'conradmarcarelli': {'similar': {'arshilgorki',
#    'bradleiwalkertomlin',
#    'hanhofmann',
#    'jamebrook',
#    'raoulhagu'},
#   'in_category_mean': 0.5},
#  'nicholamarsicano': {'similar': {'clyfford',
#    'estebanvicent',
#    'giorgiocavallon',
#    'hanhofmann',
#    'jacktworkov',
#    'thomasill'},
#   'in_category_mean': 0.6},
#  'joanmitchel': {'similar': {'helenfrankenthal',
#    'louisnevelson',
#    'robertmotherwel',
#    'twombl'},
#   'in_category_mean': 0.4},
#  'robertmotherwel': {'similar': {'helenfrankenthal',
#    'jacksonpollock',
#    'reinhardt',
#    'willemkoon'},
#   'in_category_mean': 0.4},
#  'louisnevelson': {'similar': {'helenfrankenthal', 'joanmitchel'},
#   'in_category_mean': 0.2},
#  'barnettnewman': {'similar': {'helenfrankenthal',
#    'jamerosati',
#    'louisnevelson',
#    'markrothko',
#    'miltonresnick',
#    'philipguston',
#    'robertgoodnough'},
#   'in_category_mean': 0.7},
#  'isamunoguchi': {'similar': {'alexandcalder',
#    'davidsmith',
#    'herbertferber',
#    'reinhardt',
#    'theodorroszak',
#    'willemkoon'},
#   'in_category_mean': 0.6},
#  'jacksonpollock': {'similar': {'willemkoon'}, 'in_category_mean': 0.1},
#  'richardpousettdart': {'similar': {'soniagechtoff'}, 'in_category_mean': 0.1},
#  'reinhardt': {'similar': {'alexandcalder',
#    'josephcornel',
#    'robertmotherwel',
#    'willemkoon'},
#   'in_category_mean': 0.4},
#  'miltonresnick': {'similar': {'barnettnewman', 'robertgoodnough'},
#   'in_category_mean': 0.2},
#  'jeanpaulriopel': {'similar': {'jackbush'}, 'in_category_mean': 0.1},
#  'jamerosati': {'similar': {'barnettnewman', 'louisbourgeoi'},
#   'in_category_mean': 0.2},
#  'theodorroszak': {'similar': {'alexandcalder',
#    'davidhare',
#    'davidsmith',
#    'herbertferber'},
#   'in_category_mean': 0.4},
#  'markrothko': {'similar': {'barnettnewman',
#    'gracehartigan',
#    'helenfrankenthal',
#    'jacksonpollock',
#    'louisnevelson',
#    'reinhardt',
#    'robertmotherwel',
#    'willemkoon'},
#   'in_category_mean': 0.8},
#  'charlselig': {'similar': {'enricodonati', 'jamebrook'},
#   'in_category_mean': 0.2},
#  'thomasill': {'similar': {'estebanvicent',
#    'jacktworkov',
#    'leekrasner',
#    'morriloui',
#    'nicholamarsicano'},
#   'in_category_mean': 0.5},
#  'davidsmith': {'similar': {'alexandcalder', 'isamunoguchi', 'theodorroszak'},
#   'in_category_mean': 0.3},
#  'theodorostamo': {'similar': {'enricodonati', 'marktobei', 'williambaziot'},
#   'in_category_mean': 0.3},
#  'heddastern': {'similar': {'arshilgorki', 'davidsmith'},
#   'in_category_mean': 0.2},
#  'clyfford': {'similar': {'adolphgottlieb',
#    'giorgiocavallon',
#    'jacktworkov',
#    'morriloui',
#    'nicholamarsicano'},
#   'in_category_mean': 0.5},
#  'marktobei': {'similar': {'alexandcalder', 'arshilgorki', 'jacksonpollock'},
#   'in_category_mean': 0.3},
#  'bradleiwalkertomlin': {'similar': {'arshilgorki',
#    'jacksonpollock',
#    'jamebrook',
#    'markrothko',
#    'willemkoon',
#    'williambaziot'},
#   'in_category_mean': 0.6},
#  'twombl': {'similar': {'johnchamberlain'}, 'in_category_mean': 0.1},
#  'jacktworkov': {'similar': {'clyfford',
#    'estebanvicent',
#    'giorgiocavallon',
#    'leekrasner',
#    'thomasill'},
#   'in_category_mean': 0.5},
#  'estebanvicent': {'similar': {'giorgiocavallon',
#    'jacktworkov',
#    'leekrasner',
#    'morriloui',
#    'thomasill'},
#   'in_category_mean': 0.5}}
